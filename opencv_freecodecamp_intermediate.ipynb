# %% [markdown]
# <a href="https://colab.research.google.com/github/ganesh3/opencv-work/blob/main/opencv_freecodecamp_intermediate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Intermediate

# %%
# !git clone https://github.com/misbah4064/opencvTutorial.git
# %cd opencvTutorial/
from IPython.display import clear_output
clear_output()

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %%
# !pwd
# Out:
# /content/opencvTutorial

# %% [markdown]
# Colour Detection

# %%
img = cv2.imread("images/shapes.png")
img.shape
# Out:
# (480, 640, 3)

# %%
#BGR Image
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F8AD2E7FF10>

# %%
hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
hsv_img.shape
# Out:
# (480, 640, 3)

# %%
display = np.hstack((img, hsv_img))
cv2_imshow(display)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x480 at 0x7F8AD2E12950>

# %%
#check trackbar in opencv for upper & lower bound
#blue colour triangle
lower_blue = np.array([65,0, 0])
upper_blue = np.array([110,255,255])

#red colour circle
lower_red = np.array([0 ,0, 0])
upper_red = np.array([20,255,255])

#green colour
lower_green = np.array([46 ,0, 0])
upper_green = np.array([91,255,255])

#yellow colour
lower_yellow = np.array([21 ,0, 0])
upper_yellow= np.array([45,255,255])

#red & green colour
lower_red_green = np.array([0 ,0, 0])
upper_red_green = np.array([91,255,255])

mask1 = cv2.inRange(hsv_img, lower_blue, upper_blue)
mask2 = cv2.inRange(hsv_img, lower_red, upper_red)
mask3 = cv2.inRange(hsv_img, lower_green, upper_green)
mask4 = cv2.inRange(hsv_img, lower_red_green, upper_red_green)
mask5 = cv2.inRange(hsv_img, lower_yellow, upper_yellow)


#cv2_imshow(mask1)
#cv2_imshow(mask2)
#cv2_imshow(mask3)
#cv2_imshow(mask4)
cv2_imshow(mask5)
# Out:
# <PIL.Image.Image image mode=L size=640x480 at 0x7F8AD2DD1690>

# %%
result1 = cv2.bitwise_and(img, img, mask = mask1)
result2 = cv2.bitwise_and(img, img, mask = mask2)
result3 = cv2.bitwise_and(img, img, mask = mask3)
result4 = cv2.bitwise_and(img, img, mask = mask4)
result5 = cv2.bitwise_and(img, img, mask = mask5)


#cv2_imshow(result1)
#cv2_imshow(result2)
#cv2_imshow(result3)
#cv2_imshow(result4)
cv2_imshow(result5)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F8AE2A1D690>

# %% [markdown]
# ###Face Detection

# %%
#images trained on specific size & colour
face_cascade = cv2.CascadeClassifier("files/haarcascade_frontalface_default.xml")

# %%
face_img = cv2.imread("images/person.jpg")
face_img.shape
# Out:
# (435, 640, 3)

# %%
cv2_imshow(face_img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x435 at 0x7F8AD2CE0910>

# %%
#convert colour function
face_gray = cv2.cvtColor(face_img, cv2.COLOR_BGR2GRAY)
cv2_imshow(face_gray)
# Out:
# <PIL.Image.Image image mode=L size=640x435 at 0x7F8AD2CE8790>

# %%
face_detect_coord = face_cascade.detectMultiScale(face_gray, 1.3, 5)
for x,y,w,h in face_detect_coord:
  cv2.rectangle(face_img, (x, y), (x+w, y+h), (0, 255, 0), 3)

cv2_imshow(face_img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x435 at 0x7F8AD2CE6410>
